# %%
Main_path = '/home/paperspace/Source_Sep_Rea/Facebook_Transformers/'

# %%
path_of_code = Main_path+'demucs-main/demucs-main'
# !conda activate base
# !ls $path_of_code
# %cd $path_of_code
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
# CODE_OF_CONDUCT.md  environment-cpu.yml   mypy.ini		    setup.cfg
# conf		    environment-cuda.yml  nohup.out		    setup.py
# CONTRIBUTING.md     hubconf.py		  outputs		    test.mp3
# demucs		    LICENSE		  outputs.tar.gz	    tools
# Demucs.ipynb	    Makefile		  README.md
# demucs.png	    MANIFEST.in		  requirements_minimal.txt
# docs		    metadata		  requirements.txt
# /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main

# %%
#runs with:
#!tar xvf outputs.tar.gz
#!dora run -d -f 81de367c batch_size=4 dset.segment=8 hdemucs.channels=24 test.workers= epochs=20
run_path = Main_path + 'demucs-main/demucs-main/outputs/xps/22d99e8f/train.log'
# !cat $run_path
# Out:
# [2022-08-25 06:46:06,019][demucs.train][INFO] - For logs, checkpoints and samples check /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/22d99e8f
# [2022-08-25 06:46:06,031][dora.distrib][INFO] - world_size is 1, skipping init.
# [2022-08-25 06:46:15,045][demucs.train][INFO] - train/valid set size: 18626 14
# [2022-08-25 06:46:15,293][demucs.solver][INFO] - ----------------------------------------------------------------------
# [2022-08-25 06:46:15,293][demucs.solver][INFO] - Training...
# [2022-08-25 07:31:42,497][demucs.solver][INFO] - Train | Epoch 1 | 1164/4656 | 0.43 it/sec | Loss 0.2023 | Reco 0.2012 | Grad 0.1009 | Penalty 110.0660
# [2022-08-25 08:17:00,586][demucs.solver][INFO] - Train | Epoch 1 | 2328/4656 | 0.43 it/sec | Loss 0.1926 | Reco 0.1914 | Grad 0.1006 | Penalty 122.4590
# [2022-08-25 09:02:22,695][demucs.solver][INFO] - Train | Epoch 1 | 3492/4656 | 0.43 it/sec | Loss 0.1867 | Reco 0.1854 | Grad 0.1047 | Penalty 125.3398
# ...

# %%
run_path = Main_path + 'demucs-main/demucs-main/outputs/xps/a68eaf9b/train.log'
# !cat $run_path
# Out:
# [2022-09-07 19:47:33,358][demucs.train][INFO] - For logs, checkpoints and samples check /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/a68eaf9b
# [2022-09-07 19:47:33,371][dora.distrib][INFO] - world_size is 1, skipping init.
# [2022-09-07 19:47:42,153][demucs.train][INFO] - train/valid set size: 18626 14
# [2022-09-07 19:47:42,401][demucs.solver][INFO] - Loading from /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/22d99e8f/checkpoint.th
# [2022-09-07 19:47:45,132][demucs.solver][INFO] - ----------------------------------------------------------------------
# [2022-09-07 19:47:45,133][demucs.solver][INFO] - Training...
# [2022-09-07 20:33:13,928][demucs.solver][INFO] - Train | Epoch 1 | 1164/4656 | 0.43 it/sec | Loss 0.1051 | Reco 0.1031 | Grad 0.1022 | Penalty 198.9982
# ...

# %%
run_path = Main_path + 'demucs-main/demucs-main/outputs/xps/538354e6/train.log'
# !cat $run_path
# Out:
# [2022-09-10 16:18:02,526][demucs.train][INFO] - For logs, checkpoints and samples check /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/538354e6
# [2022-09-10 16:18:02,541][dora.distrib][INFO] - world_size is 1, skipping init.
# [2022-09-10 16:18:11,530][demucs.train][INFO] - train/valid set size: 18626 14
# [2022-09-10 16:18:11,790][demucs.solver][INFO] - Loading from /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/a68eaf9b/checkpoint.th
# [2022-09-10 16:18:15,479][demucs.solver][INFO] - ----------------------------------------------------------------------
# [2022-09-10 16:18:15,479][demucs.solver][INFO] - Training...
# [2022-09-10 17:04:02,439][demucs.solver][INFO] - Train | Epoch 1 | 1164/4656 | 0.42 it/sec | Loss 0.0976 | Reco 0.0954 | Grad 0.0919 | Penalty 224.8514
# ...

# %%
#Running with lr cut by half
#runs with:
#!dora run -d -f 538354e6 continue_from=538354e6 epochs=20 optim.lr=0.00025 
run_path = Main_path + 'demucs-main/demucs-main/outputs/xps/5e8ce54e/train.log'
# !cat $run_path
# Out:
# [2022-09-20 14:26:11,989][demucs.train][INFO] - For logs, checkpoints and samples check /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/5e8ce54e
# [2022-09-20 14:26:12,000][dora.distrib][INFO] - world_size is 1, skipping init.
# [2022-09-20 14:26:15,881][demucs.train][INFO] - train/valid set size: 18626 14
# [2022-09-20 14:26:16,091][demucs.solver][INFO] - Loading from /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/538354000000.0/checkpoint.th
# [2022-09-20 14:31:43,156][demucs.train][INFO] - For logs, checkpoints and samples check /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/5e8ce54e
# [2022-09-20 14:31:43,167][dora.distrib][INFO] - world_size is 1, skipping init.
# [2022-09-20 14:31:47,046][demucs.train][INFO] - train/valid set size: 18626 14
# ...

# %%
run_path = Main_path + 'demucs-main/demucs-main/outputs/xps/10d3d91d/train.log'
# !cat $run_path
# Out:
# cat: more: No such file or directory
# [2022-09-25 16:37:27,399][demucs.train][INFO] - For logs, checkpoints and samples check /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/10d3d91d
# [2022-09-25 16:37:27,412][dora.distrib][INFO] - world_size is 1, skipping init.
# [2022-09-25 16:37:36,311][demucs.train][INFO] - train/valid set size: 18626 14
# [2022-09-25 16:37:36,554][demucs.solver][INFO] - Loading from /home/paperspace/Source_Sep_Rea/Facebook_Transformers/demucs-main/demucs-main/outputs/xps/5e8ce54e/checkpoint.th
# [2022-09-25 16:37:37,793][demucs.solver][INFO] - ----------------------------------------------------------------------
# [2022-09-25 16:37:37,793][demucs.solver][INFO] - Training...
# [2022-09-25 17:23:26,629][demucs.solver][INFO] - Train | Epoch 1 | 1164/4656 | 0.42 it/sec | Loss 0.0890 | Reco 0.0871 | Grad 0.0796 | Penalty 190.5043
# ...
